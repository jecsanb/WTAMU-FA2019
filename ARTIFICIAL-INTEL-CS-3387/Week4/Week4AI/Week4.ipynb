# %% [markdown]
# # Knowledge representation - Chapters 12, 7 and 9
#
# **Note:** The presentation was made using instruction material with little to no edits

# %% [markdown]
# ## Agenda
#
# - Quiz
# - Discussing the Quiz
# - Today's participation grade
# - Discussing team projects/career fair
# - Knowledge representation
# - Predicate logic
# - Survey

# %% [markdown]
# ## Discussing the Quiz
#
# - What went wrong?
# - What went right?
# - How to improve?

# %% [markdown]
# ## This week's participation grade
#
# There are 14 concepts that I would like to discuss today.
#
# I have choosen one concept that you will comment upon for each of you
# - Ontological engineering - Musa
# - Categories and Objects - Rachel
# - Events - Daniel
# - Mental Events and Mental Objects - London
# - Reasoning Systems for Categories - Atef
# - Reasoning with Default Information - Ibsa
# - Knowledge-Based Agents - Jecsan
# - Logic - An
# - Propositional Logic - Steven
# - Propositional Theorem Proving - Andrew
# - Effective Propositional Model Checking - TJ Buecker
# - Agents Based on Propostional Logic - Hunter
# - Forward Chaining - Matthew
# - Backward Chaining - TJ Moore
#
# To get a full credit, you need to provide the following:
# 1. Explanation of the concept - 20 points
# 2. Explanation of the example that will serve to show what the concept is about - 20 points
# 3. The code that runs on the example - 20 points
# 4. Documentation of the code - 20 points
# 5. Blog of your experience - 20 points
#
# The most important part of the blog of your experience will be what contributed most to your learning experience? How much time you spent on the research and can you relate your real life experience with what you are learning about, if at all possible?
#
# Please, finish your task early such that we could comment and improve your learning experience. Please, note: If you **understand** all the concepts covered today, that is **all you need for the quiz**!
#
# If we don't get to discuss your concept in the class reach out to me by WTClass Course Message or come to my office during office hours, Monday 10am - 12 noon (remember)

# %% [markdown]
# ## Discussing Team Projects
#
# Here I would like to draw your attention to next week's Career Fair activities:
#
# - When: Wednesday Sept 25, 2019 at 5:30pm - 8pm
# - Where: Legacy Hall
# - What: Pre-Fair Networking Event
# - Companies attending:
#     1. Bank of America
#     2. Broadcom (CA Technologies)
#     3. CGI
#     4. Imperva
#     5. Rocket Software
#     6. Turnkey Computer Systems
#     7. Visa
#
# - Career Fair
# - Imperva coming to speak with you in class
#
# Career Fair Prep and learning suggestions:
# If someone did it you can do it too, and you can do even more if you slow down when in rush, hurry up when you are not in a rush. Idle time is wasted time and time is wasted in the haste and procrastination.
#
# My grandfather (having 50 years of teaching experience and almost the same amount of time spent in doing the research into how people study and how they should be thought) shared with me his way of studying:
#
# - Keep as detailed notes as possible,
# - Review what you have studied 24 hours after you did without looking at your notes and keep notes of what you remember
# - Improve your notes and clarify everything that you didn't remember
# - Review after a week using the same process
# - Review after 7 weeks using the same process
#
# The same goes to communication with people. Send a reminder not more than 24 hours after you met someone, then follow up after a week and follow up after 7 weeks even if nothing happens in between.
#
# Engineering Internship Panel Discussion important points:
#
# - Locking yourself in a position
#
# - Always ask questions (does that sound familiar?)
#
# - Have a complete linkedin (enter all the information about what you have been working on) Enter the keywords companies are looking for
#
# - Complete career history
# - Continuity
# - Honesty
#
# - Should we interview for jobs that we don’t want?
#
# - Research the companies speak with company representatives. What if those companies are not here? How to get there?
#
# - Internships can lead towards a full time job, but not necessarily directly
#
# - It's never to early to look for a job/internship

# %% [markdown]
# ## Real world Problem (storage domain)
#
# - For a given
#     - user workload w1 and
#     - user required performance p1
# - Find the suitable hardware + cache configuration that satisfies user workload w1 and perf p1.
# - Additional: Give the optimal solution that satisfies the condition (defined as: cheapest hardware in $$$ costs or min energy/cooling needs xx)
# - There is no direct math relationship between workload, perf, and hardware + cache
# - Therefore we should search through a lot of experiment data
# - Search is expensive we should avoid searching through all the empirical data-set
#     - Therefore we use optimization (or narrow down solution space)

# %% [markdown]
# ## Knowledge
#
# - Goal: common sense reasoning
# - Need to represent the knowledge about the world
# - Types of Knowledge
#     - objects
#     - events
#     - procedures
#     - relations
#     - mental states
#     - meta knowledge

# %% [markdown]
# ## Properties of Representation Systems
#
# - Representational adequacy
#     - Ability to represent the required knowledge
# - Inferential adequacy
#     - ability to manipulate knowledge
#         - produce new knowledge
# - Inferential efficiency
#     - ability to direct inference methods into productive directions
#     - ability to respond with limited resources (time, storage)
# - Acquisitional efficiency
#     - ability to acquire new knowledge
#     - ideally, automatically

# %% [markdown]
# ## Categories
#
# - Specific objects
#     - e.g. AI (as a CS course)
# - General category
#     - e.g. CS_Courses
#     - categories as relationships CS_Courses(AI)
#     - reification of predicate: CS_Courses
#         - use in other predicates Member(AI, Courses)
#         - abbreviated to AI $\in$ Courses
# - Subcategories
#     - e.g. Subset(CS_Courses, College_Courses)
#     - abbreviated as CS_Courses $\subset$ College_Courses
#
# - Taxonomy: System of categories and subcategories
#
# ### Basic Relations for Categories
#
# - Disjoint({Animals, Vegetables})
# - ExhaustiveDecomposition({Americans, Canadians, Mexicans},NorthAmericans)
# - Partition({Males, Females}, Animals)
# - These properties can be defined with first order logic
#
# ### Physical Composition
#
# - Basic relations such as PartOf
#     - PartOf(Bucharest, Romania)
#     - PartOf(Romania, EasternEurope)
#     - PartOf(EasternEurope, Europe)
#     - PartOf(Europe, Earth)
# - Can be used to define composite objects
#
# Biped(a) $\implies$ $\exists l_1$, $l_2$, b Leg($l_1$) $\land$ Leg($l_2$) $\land$ Body(b)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\land$ PartOf($l_1$, a) $\land$ PartOf($l_2$, a) $\land$ PartOf(b, a)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\land$ Attached($l_1$, b) $\land$ Attached($l_2$, b)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\land l_1 \neq l_2$
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\land [\forall l_3$ Leg($l_3$) $\land$ PartOf($l_3$ a) $\implies$ ($l_3 = l_1 \lor l_3 = l_2)]$
#
# ### Prototypes
#
# - Natural categories are hard to define
# - There is no set of features that applies to all instances
# - But: prototypes have such properties
# - Select typical members of categories
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\exists$b $\in$ Typical(Bird) $\implies$ CanFly(b)
#
# ### Hierarchies and Inheritance
#
# - Hierarchy (or taxonomy) is a natural way to structure categories
# - Importance of abstraction in remembering and reasoning
#     - groups of things share properties in the world
#     - we do not have to repeat definitions
# - Example: saying "elephants are mammals" is sufficient to know a lot about them
# - Inheritance is the result of reasoning over paths in a hierarchy:
#
#     "does a inherit from b?"
#
#     is the same as
#
#     "is b in the transitive closure of :IS-A (or subsumption) from a?"
#
# ### Graphical Representation of Inheritance
#
# - IS relations:
#
# ![GRI.png](GRI.png)
#
# - Clyde is an Elephant, Elephant is Gray
# - Reasoning with paths and conclusions they represent ("Transitive relations")
# - Transitive closure
#     - Clyde is Elephant, Elephant is Gray $\implies$ Clyde is Gray
#
# ### Strict Inheritance
#
# ![SI.png](SI.png)
#
# - Conclusions produced by complete transitive closure on all paths (any traversal procedure will do)
# - All reachable nodes are implied
#
# ### Latice Structure with Strict Inheritance
#
# ![LSSI.png](LSSI.png)
#
# - Multiple AND ($\land$) parents (= multiple inheritance)
# - Trees: all conclusions you can reach by any paths are supported
#
# ### Defeasible Inheritance
#
# ![DI.png](DI.png)
#
# - Inherited properties do not always hold, and can be overridden (defeated)
# - Conclusions determined by searching upward from focus node and selecting first version of property you want
#
# ### Shortest Path Heuristic
#
# - Links have polarity (positive or negative)
# - Use shortest path heuristic to determine which polarity counts
# - As a result, not all paths count in generating conclusions
# - Some are "preempted" but some are "admissible"
# - Think of paths as arguments in support of conclusions
#
# ### Problem Ambiguity
#
# ![Ambiguity.png](Ambiguity.png)
#
# - There may be no single shortest path
# - Conclusion is changed by adding additional categories, edges
#     - Explicit handling of ambiguous reasoning chains
#         - distinguish between ambiguous and unambiguous chains
#         - preference for some extensions over others (default logic)
#         - credulous vs. skeptical reasoning

# %% [markdown]
# ## Ontologies
#
#
# ![lecture-knowledge-representation.jpg](lecture-knowledge-representation.jpg)
#
# - Organize knowledge about everything in a single taxonomy

# %% [markdown]
# ## Simple Relational Knowledge
#
# - We often want represent a large number of facts that follow a simple pattern
#
# ![SRK.png](SRK.png)
#
# - Database table in relational database

# %% [markdown]
# ## Frames
#
#
# - A frame is a collection of attributes or slots and associated values that describe some real world entity
# - Each frame represents
#     - a class, or
#     - an instance (an element of a class)
#
# ![Frames.png](Frames.png)

# %% [markdown]
# ## Knowledge discovery
#
# - Information retrieval when facing a new situation
#     - information is stored in frames with slots
#     - some of the slots trigger actions, causing new situations
# - Frames are templates
#     - need to be filled-in in a situation
#     - filling them causes the agent to undertake actions and retrieve other frames
# - Frames are extensions of record datatype in databases
# - Also very similar to object oriented processing
#
# ### Flexibility in Frames
#
# - Slots in a frame can contain
#     - information for choosing a frame in a situation
#     - relationship between this and other frames
#     - procedures to carry out after various slots filled
#     - default information to use when input is missing
#     - blank slots - left blank unless required for a task
#     - other frames, which gives a hierarchy
#
# ![FramesH.jpg](FramesH.jpg)

# %% [markdown]
# ## Events
#
# - So far, facts were treated as true independent of time
# - Events: need to describe what is true, when something is happening
# - For instance: Flying event
#     - E $\in$ Flyings
#     - Flyer(E,Shankar)
#     - Origin(E,SanFrancisco)
#     - Destination(E,Baltimore)
# - The event may or may not ongoing during a specific time t: Happens(E, t)
# - In general, facts that are true only at specific time points are called fluents e.g., At(Shankar;Baltimore)
# ![FramesH.jpg](FramesH.jpg)
#
# ### Predicates of events
#
# - T(f, t) - Fluent f is true at time t
# - Happens(e, i) - Event e happens over the time interval i
# - Initiates(e, f, t) - Event e causes fluent f to start at time t
# - Terminates(e, f, t) - Event e causes fluent f to end at time t
# - Clipped(e, f, i) - Fluent f ceases to be true at some point during time interval i
# - Restored(e, f, i) - Fluent f becomes true at some point during time interval i
#
# ### Time Intervals
#
# - There are a lot benefits to represent time in terms of intervals
#     - moments: zero duration
#     - extended intervals: positive time duration
# - Allows the definition of
#     - time interval meeting End(i1) = Start(I2)
#     - time interval preceding another
#     - during: time interval subset of other
#     - overlap: time interval intersect, but neither is strict subset
#     - beginning, end, indentiy of time intervals
# - Example: President(USA; t) match different persons for different t
#
# ### Scripts
#
# - Definition
#     - A script is a structured representation describing a stereotyped sequence of events in a particular context
# - Scripts are used to organize events in knowledge bases
# - Scripts are very related to the idea of frames
#
# ### Components of a Script
#
# - A script is composed of several components
# - Entry conditions that must be true for the script to be called
# - Results or facts that are true once the script has terminated
# - Props or the "things" that make up the content of the script
# - Roles are the actions that the individual participants perform
# - Scenes which present temporal aspects of the script
#
# ### Canonical Example: Restaurant Visit
#
# - Objects: tables, menu, food, check, money, ...
# - Roles: customer, waiter, cook, cashier, owner, ...
# - Entry conditions: customer hungry, customer has money
# - Results: customer not hungry, customer has less money, owner more money, ...
# - Scenes
#     - Scene 1: Entering
#         - customer enters restaurant
#         - customers looks at tables
#         - customer decides where to sit
#         - ...
#     - Scene 2: Ordering
#         - waiter brings menu
#         - ...
#     - ...
#
# ![ScriptActions.jpg](ScriptActions.jpg)
# ![DetailedScript.jpg](DetailedScript.jpg)

# %% [markdown]
# ### Please open [chapter07.pdf](chapter07.pdf)
# ### Please open [chapter09.pdf](chapter09.pdf)

# %% [markdown]
# ## Summary
#
# - We continued discussing solutions to race conditions with blocking the processes
#     - monitors
#     - message passing
#     - barriers
# - You got 6 concepts to work on in groups for today's class participation grade research
#     - sleep and wakeup
#     - semaphores
#     - mutexes
#     - monitors
#     - message passing
#     - barriers
# - Next week we will tackle classical interprocess communication problems chapter 2.5 and after that we will tackle scheduling

# %% [markdown]
# ## Survey
#
# Please, open the WTClass and provide feedback upon how did you like this class. This is optional but highly appreciated.
